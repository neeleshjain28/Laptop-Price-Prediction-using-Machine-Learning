# %%
# !pip install pandas
# !pip install scikit-learn

import pandas as pd
import numpy as np

# %%
df = pd.read_csv('laptopPrice.csv')
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    str
#  1   processor_brand    823 non-null    str
#  2   processor_name     823 non-null    str
#  3   processor_gnrtn    823 non-null    str
#  4   ram_gb             823 non-null    str
#  5   ram_type           823 non-null    str
#  6   ssd                823 non-null    str
#  7   hdd                823 non-null    str
#  8   os                 823 non-null    str
#  9   os_bit             823 non-null    str
#  10  graphic_card_gb    823 non-null    str
#  11  weight             823 non-null    str
#  12  warranty           823 non-null    str
#  13  Touchscreen        823 non-null    str
#  14  msoffice           823 non-null    str
#  15  Price              823 non-null    int64
#  16  rating             823 non-null    str
# ...

# %%
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
df.tail()
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 818  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 819  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 820  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 821  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 822   512 GB  0 GB      DOS  64-bit            0 GB  ThinNlight  No warranty
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    str
#  1   processor_brand    823 non-null    str
#  2   processor_name     823 non-null    str
#  3   processor_gnrtn    823 non-null    str
#  4   ram_gb             823 non-null    str
#  5   ram_type           823 non-null    str
#  6   ssd                823 non-null    str
#  7   hdd                823 non-null    str
#  8   os                 823 non-null    str
#  9   os_bit             823 non-null    str
#  10  graphic_card_gb    823 non-null    str
#  11  weight             823 non-null    str
#  12  warranty           823 non-null    str
#  13  Touchscreen        823 non-null    str
#  14  msoffice           823 non-null    str
#  15  Price              823 non-null    int64
#  16  rating             823 non-null    str
# ...

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='str')

# %%
df.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
df.isnull().sum()
df.dropna(inplace=True)

# %%
df['brand'].unique()
# Out:
# <StringArray>
# ['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE']
# Length: 8, dtype: str

# %%
df['processor_brand'].unique()
# Out:
# <StringArray>
# ['Intel', 'AMD', 'M1']
# Length: 3, dtype: str

# %%
processor_brand={'Intel':1, 'AMD':2,'M1':3}

# %%
df['processor_name'].unique()
# Out:
# <StringArray>
# [     'Core i3',      'Core i5', 'Celeron Dual',      'Ryzen 5',
#       'Core i7',      'Core i9',           'M1', 'Pentium Quad',
#       'Ryzen 3',      'Ryzen 7',      'Ryzen 9']
# Length: 11, dtype: str

# %%
processor_name={'Core i3':1, 'Core i5':2, 'Core i7':3, 'Ryzen 3':4, 'Ryzen 5':5, 'Ryzen 7':6, 'M1':7,'celeron':8,'pentium Quad Core':9,'Core i9':10,'Ryzen 9':11}

# %%
processor_brand={'Intel':1, 'AMD':2, 'Apple':3}
df['processor_brand']=df['processor_brand'].map(processor_brand)

# %%
df['ram_gb'].unique()
# Out:
# <StringArray>
# ['4 GB', '8 GB', '16 GB', '32 GB']
# Length: 4, dtype: str

# %%
ram_gb={4:1, 8:2, 12:3, 16:4, 24:5, 32:6}

# %%
df['ram_gb']=df['ram_gb'].map(ram_gb)

# %%
# Example: If 'Unnamed: 0' or index column exists
# df.drop('Unnamed: 0', axis=1, inplace=True)

df.drop(['Unnamed: 0'], axis=1, inplace=True, errors='ignore')

# %%
char = df.select_dtypes(include='object')
num = df.select_dtypes(exclude='object')

char.head()
num.head()
# Out:
# C:\Users\creat\AppData\Local\Temp\ipykernel_20364\102458178.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   char = df.select_dtypes(include='object')
#    processor_brand  ram_gb  Price  Number of Ratings  Number of Reviews
# 0              1.0     NaN  34649                  3                  0
# 1              1.0     NaN  38999                 65                  5
# 2              1.0     NaN  39999                  8                  1
# 3              1.0     NaN  69990                  0                  0
# ...

# %%
brand_dict={'ASUS':1, 'Lenovo':2, 'acer':3, 'Avita':4, 'HP':5, 'DELL':6, 'MSI':7, 'APPLE':8}

# %%
df['brand']=df['brand'].map(brand_dict)

# %%
df['processor_name'].unique()
# Out:
# <StringArray>
# [     'Core i3',      'Core i5', 'Celeron Dual',      'Ryzen 5',
#       'Core i7',      'Core i9',           'M1', 'Pentium Quad',
#       'Ryzen 3',      'Ryzen 7',      'Ryzen 9']
# Length: 11, dtype: str

# %%
touchscreen_dict={'No':0,'Yes':1}
df['Touchscreen'] = df['Touchscreen'].map(touchscreen_dict)

# %%
ram_type_dict = {'DDR4':1, 'DDR3':2, 'LPDDR4':3, 'LPDDR3':4}
df['ram_type'] = df['ram_type'].map(ram_type_dict)

# %%
processor_gnrtn_dict = {'11th Gen':1, '12th Gen':2, '10th Gen':3, '9th Gen':4}
df['processor_gnrtn'] = df['processor_gnrtn'].map(processor_gnrtn_dict)

# %%
os_dict = {'Windows':1, 'macOS':2, 'Linux':3}
df['os'] = df['os'].map(os_dict)

# %%
ram_gb_dict = {'8GB':1, '16GB':2, '4GB':3, '12GB':4}
df['ram_gb'] = df['ram_gb'].map(ram_gb_dict)

# %%
ssd_dict = {'256GB SSD':1, '512GB SSD':2, '1TB SSD':3}
df['ssd'] = df['ssd'].map(ssd_dict)

# %%
os_bit_dict = {'64-bit':1, '32-bit':2}
df['os_bit'] = df['os_bit'].map(os_bit_dict)

# %%
graphic_card_gb_dict = {'4GB':1, '8GB':2, '12GB':3, '16GB':4}
df['graphic_card_gb'] = df['graphic_card_gb'].map(graphic_card_gb_dict)

# %%
weight_dict = {'1.5 kg':1, '2.0 kg':2, '1.8 kg':3, '2.5 kg':4}
df['weight'] = df['weight'].map(weight_dict)

# %%
warranty_dict = {'1 Year':1, '2 Year':2}
df['warranty'] = df['warranty'].map(warranty_dict)

# %%
msoffice_dict = {'Yes':1, 'No':2}
df['msoffice'] = df['msoffice'].map(msoffice_dict)

# %%
rating_dict = {'4.0 out of 5 stars':1, '4.5 out of 5 stars':2, '3.5 out of 5 stars':3, '3.0 out of 5 stars':4, '2.5 out of 5 stars':5}
df['rating'] = df['rating'].map(rating_dict)

# %%
df['Number of Ratings']
# Out:
# 0       3
# 1      65
# 2       8
# 3       0
# 4       0
#        ..
# 818     0
# 819     0
# 820     0
# 821     0
# 822    18
# Name: Number of Ratings, Length: 823, dtype: int64

# %%
os_dict = {'Windows 11 Home':1, 'Windows 10 Home':2, 'Windows 11 Pro':3, 'Windows 10 Pro':4}
df['os'] = df['os'].map(os_dict)

# %%
hdd_dict = {'256GB SSD':1, '1TB HDD':2, '512GB SSD':3, '128GB SSD + 1TB HDD':4}
df['hdd'] = df['hdd'].map(hdd_dict)

# %%
df.to_csv('clean_laptop_data.csv', index=False)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
x = df.drop('Price', axis=1)
y = df[['Price']]

# %%
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (658, 18) (165, 18) (658, 1) (165, 1)

# %%
x_train
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 239      1                1               2                3       3
# 707      3                2               4                2       1
# 759      1                2              10                2       1
# 432      1                1               2                1       2
# 299      1                1               2                3       2
# ..     ...              ...             ...              ...     ...
# 71       2                1               1                3       1
# 106      5                1               1                3       2
# 270      2                1               2                3       2
# 435      7                1               2                1       2
# 102      1                1               1                3       2
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
x_test
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 610      8                3               7                1       2
# 174      1                1               1                3       2
# 67       2                1               1                1       1
# 168      6                1               1                1       2
# 275      2                1               2                1       2
# ..     ...              ...             ...              ...     ...
# 290      2                1               2                3       2
# 211      5                1               2                5       2
# 448      3                1               2                3       2
# 766      2                2              10                2       1
# 526      2                1               5                1       3
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
# The split is already done and variables are available.
# No need to split again.

# %%
x_train
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 239      1                1               2                3       3
# 707      3                2               4                2       1
# 759      1                2              10                2       1
# 432      1                1               2                1       2
# 299      1                1               2                3       2
# ..     ...              ...             ...              ...     ...
# 71       2                1               1                3       1
# 106      5                1               1                3       2
# 270      2                1               2                3       2
# 435      7                1               2                1       2
# 102      1                1               1                3       2
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer

# Impute missing values in x_train and x_test
imputer = SimpleImputer(strategy='mean')
x_train_imputed = imputer.fit_transform(x_train)
x_test_imputed = imputer.transform(x_test)

lr = LinearRegression()
lr.fit(x_train_imputed, y_train)

pred_lr = lr.predict(x_test_imputed)
# Out:
# e:\Data Science\.venv\Lib\site-packages\sklearn\impute\_base.py:641: UserWarning: Skipping features without any observed values: ['msoffice']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# e:\Data Science\.venv\Lib\site-packages\sklearn\impute\_base.py:641: UserWarning: Skipping features without any observed values: ['msoffice']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %%
x_test
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 610      8                3               7                1       2
# 174      1                1               1                3       2
# 67       2                1               1                1       1
# 168      6                1               1                1       2
# 275      2                1               2                1       2
# ..     ...              ...             ...              ...     ...
# 290      2                1               2                3       2
# 211      5                1               2                5       2
# 448      3                1               2                3       2
# 766      2                2              10                2       1
# 526      2                1               5                1       3
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
x_train
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 239      1                1               2                3       3
# 707      3                2               4                2       1
# 759      1                2              10                2       1
# 432      1                1               2                1       2
# 299      1                1               2                3       2
# ..     ...              ...             ...              ...     ...
# 71       2                1               1                3       1
# 106      5                1               1                3       2
# 270      2                1               2                3       2
# 435      7                1               2                1       2
# 102      1                1               1                3       2
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
y_train
# Out:
#       Price
# 239   65990
# 707   44990
# 759   72400
# 432   83990
# 299   72990
# ..      ...
# 71    39998
# 106   44990
# 270   64990
# 435  179990
# 102   41990
#
# [658 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

rfg = RandomForestRegressor(random_state=42)
rfg.fit(x_train, y_train.values.ravel())

pred = rfg.predict(x_test)

# %%
pred
# Out:
# array([ 99820.        ,  39725.99      ,  39239.74      ,  41312.89      ,
#         75916.5       ,  70765.59      , 160971.2       ,  36933.64857143,
#         53673.55      ,  59129.84      , 154763.4547619 ,  63315.24666667,
#         85371.48666667,  57734.36      ,  58647.06      ,  47020.17      ,
#         44043.78666667,  61058.07      ,  57077.37      ,  95094.645     ,
#        137687.01380952,  63960.02      ,  78377.79      ,  61470.5       ,
#         81640.1       ,  71353.91      ,  63802.605     ,  60714.035     ,
#         39643.2       ,  41107.6       ,  73462.89833333,  82745.06333333,
#         64195.52      ,  43725.67      ,  63476.29      , 142498.        ,
#         55859.93      ,  42453.48      ,  89898.67      ,  37228.25      ,
#         61651.16      ,  47093.23      ,  61599.58297619, 113312.64      ,
#         59837.62      ,  41712.1       ,  59865.925     ,  53847.79      ,
# ...
